# %%
# optimization.py

import argparse
import numpy as np
import scipy.special
import matplotlib.pyplot as plt

### 
# IMPLEMENT ME! REPLACE WITH YOUR ANSWER TO PART 1B
OPTIMAL_STEP_SIZE = 1.0
###

def _parse_args():
    """
    Command-line arguments to the system.
    :return: the parsed args bundle
    """
    parser = argparse.ArgumentParser(description='optimization.py')
    parser.add_argument('--func', type=str, default='QUAD', help='function to optimize (QUAD or NN)')
    parser.add_argument('--lr', type=float, default=1., help='learning rate')
    parser.add_argument('--weight_decay', type=float, default=0., help='weight decay')
    parser.add_argument('--epochs', type=int, default=100, help='number of epochs')
    args = parser.parse_args()
    return args


def quadratic(x1, x2):
    """
    Quadratic function of two variables
    :param x1: first coordinate
    :param x2: second coordinate
    :return:
    """
    return (x1 - 1) ** 2 + 8 * (x2 - 1) ** 2


def quadratic_grad(x1, x2):
    """
    Should return a numpy array containing the gradient of the quadratic function defined above evaluated at the point
    :param x1: first coordinate
    :param x2: second coordinate
    :return: a two-dimensional numpy array containing the gradient
    """
    return np.array([2 * (x1 - 1), 16 * (x2 - 1)])
    #raise Exception("Implement me!")


def sgd_test_quadratic(args):
    xlist = np.linspace(-3.0, 3.0, 100)
    ylist = np.linspace(-3.0, 3.0, 100)
    X, Y = np.meshgrid(xlist, ylist)
   
    Z = quadratic(X, Y)
    plt.figure()

    # Track the points visited here
    points_history = []
    curr_point = np.array([0, 0])
    for iter in range(0, args.epochs):
        grad = quadratic_grad(curr_point[0], curr_point[1])
        if len(grad) != 2:
            raise Exception("Gradient must be a two-dimensional array (vector containing [df/dx1, df/dx2])")
        next_point = curr_point - args.lr * grad
        points_history.append(curr_point)
        formatted_next_point = f"[{', '.join(f'{n:07.5f}' for n in next_point)}]"
        #formatted_diff = f"[{', '.join(f'{n:07.5f}' for n in next_point)}]"

        #print("Point after epoch %i: %07.4f %07.4f" % (iter, repr(next_point), ([1, 1] - next_point) < 0.1))
        print("Point after epoch %02.i: %s %s" % (iter, formatted_next_point, ([1, 1] - next_point) < 0.1))
        curr_point = next_point
    points_history.append(curr_point)
    cp = plt.contourf(X, Y, Z)
    plt.colorbar(cp)
    plt.plot([p[0] for p in points_history], [p[1] for p in points_history], color='k', linestyle='-', linewidth=1, marker=".")
    plt.title('SGD on quadratic')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    # exit()

#args = _parse_args()

class FakeArgs():
    def __init__(self):
        # Comments are the number of epochs to get both x1 / x2 to within 0.1 of optimal (1, 1)
        
        
        #self.lr = 0.03   # 37
        #self.lr = 0.04   # 27
        #self.lr = 0.05   # 21
        #self.lr = 0.06   # 18
        #self.lr = 0.063  # 17
        #self.lr = 0.07   # 15
        #self.lr = 0.075  # 14
        #self.lr = 0.079  # 13
        #self.lr = 0.078  # 13
        #self.lr = 0.0795 # 13
        #self.lr = 0.085  # 12
        #self.lr = 0.08   # 13
        #self.lr = 0.083  # 12
        #self.lr = 0.086  # 12
        #self.lr = 0.087  # 12
        #self.lr = 0.09   # 11
        #self.lr = 0.1    # 10
        #self.lr = 0.105  # 9
        #self.lr = 0.11   # 9
        #self.lr = 0.1115 # 9
        #self.lr = 0.112  # 9
        #self.lr = 0.1125 #10
        #self.lr = 0.115  # 12
        #self.lr = 0.12   # 26
        #self.lr = 0.13   # XXX
        #self.lr = 0.14   # XXX
        #self.lr = 0.15   # XXX
        #self.lr = 0.2    # XXX
        
        self.epochs = 100
        self.func = "QUAD"
        self.weight_decay = 0.0

args = FakeArgs()
sgd_test_quadratic( args )
# Out:
# Point after epoch 00: [0.21000, 1.68000] [False  True]
# Point after epoch 01: [0.37590, 0.53760] [False False]
# Point after epoch 02: [0.50696, 1.31443] [False  True]
# Point after epoch 03: [0.61050, 0.78619] [False False]
# Point after epoch 04: [0.69229, 1.14539] [False  True]
# Point after epoch 05: [0.75691, 0.90113] [False  True]
# Point after epoch 06: [0.80796, 1.06723] [False  True]
# Point after epoch 07: [0.84829, 0.95428] [False  True]
# Point after epoch 08: [0.88015, 1.03109] [False  True]
# Point after epoch 09: [0.90532, 0.97886] [ True  True]
# Point after epoch 10: [0.92520, 1.01437] [ True  True]
# Point after epoch 11: [0.94091, 0.99023] [ True  True]
# Point after epoch 12: [0.95332, 1.00665] [ True  True]
# Point after epoch 13: [0.96312, 0.99548] [ True  True]
# Point after epoch 14: [0.97087, 1.00307] [ True  True]
# Point after epoch 15: [0.97698, 0.99791] [ True  True]
# Point after epoch 16: [0.98182, 1.00142] [ True  True]
# Point after epoch 17: [0.98564, 0.99903] [ True  True]
# Point after epoch 18: [0.98865, 1.00066] [ True  True]
# Point after epoch 19: [0.99104, 0.99955] [ True  True]
# Point after epoch 20: [0.99292, 1.00030] [ True  True]
# Point after epoch 21: [0.99441, 0.99979] [ True  True]
# Point after epoch 22: [0.99558, 1.00014] [ True  True]
# Point after epoch 23: [0.99651, 0.99990] [ True  True]
# Point after epoch 24: [0.99724, 1.00006] [ True  True]
# Point after epoch 25: [0.99782, 0.99996] [ True  True]
# Point after epoch 26: [0.99828, 1.00003] [ True  True]
# Point after epoch 27: [0.99864, 0.99998] [ True  True]
# Point after epoch 28: [0.99893, 1.00001] [ True  True]
# Point after epoch 29: [0.99915, 0.99999] [ True  True]
# Point after epoch 30: [0.99933, 1.00001] [ True  True]
# Point after epoch 31: [0.99947, 1.00000] [ True  True]
# Point after epoch 32: [0.99958, 1.00000] [ True  True]
# Point after epoch 33: [0.99967, 1.00000] [ True  True]
# Point after epoch 34: [0.99974, 1.00000] [ True  True]
# Point after epoch 35: [0.99979, 1.00000] [ True  True]
# Point after epoch 36: [0.99984, 1.00000] [ True  True]
# Point after epoch 37: [0.99987, 1.00000] [ True  True]
# Point after epoch 38: [0.99990, 1.00000] [ True  True]
# Point after epoch 39: [0.99992, 1.00000] [ True  True]
# Point after epoch 40: [0.99994, 1.00000] [ True  True]
# Point after epoch 41: [0.99995, 1.00000] [ True  True]
# Point after epoch 42: [0.99996, 1.00000] [ True  True]
# Point after epoch 43: [0.99997, 1.00000] [ True  True]
# Point after epoch 44: [0.99998, 1.00000] [ True  True]
# Point after epoch 45: [0.99998, 1.00000] [ True  True]
# Point after epoch 46: [0.99998, 1.00000] [ True  True]
# Point after epoch 47: [0.99999, 1.00000] [ True  True]
# Point after epoch 48: [0.99999, 1.00000] [ True  True]
# Point after epoch 49: [0.99999, 1.00000] [ True  True]
# Point after epoch 50: [0.99999, 1.00000] [ True  True]
# Point after epoch 51: [1.00000, 1.00000] [ True  True]
# Point after epoch 52: [1.00000, 1.00000] [ True  True]
# Point after epoch 53: [1.00000, 1.00000] [ True  True]
# Point after epoch 54: [1.00000, 1.00000] [ True  True]
# Point after epoch 55: [1.00000, 1.00000] [ True  True]
# Point after epoch 56: [1.00000, 1.00000] [ True  True]
# Point after epoch 57: [1.00000, 1.00000] [ True  True]
# Point after epoch 58: [1.00000, 1.00000] [ True  True]
# Point after epoch 59: [1.00000, 1.00000] [ True  True]
# Point after epoch 60: [1.00000, 1.00000] [ True  True]
# Point after epoch 61: [1.00000, 1.00000] [ True  True]
# Point after epoch 62: [1.00000, 1.00000] [ True  True]
# Point after epoch 63: [1.00000, 1.00000] [ True  True]
# Point after epoch 64: [1.00000, 1.00000] [ True  True]
# Point after epoch 65: [1.00000, 1.00000] [ True  True]
# Point after epoch 66: [1.00000, 1.00000] [ True  True]
# Point after epoch 67: [1.00000, 1.00000] [ True  True]
# Point after epoch 68: [1.00000, 1.00000] [ True  True]
# Point after epoch 69: [1.00000, 1.00000] [ True  True]
# Point after epoch 70: [1.00000, 1.00000] [ True  True]
# Point after epoch 71: [1.00000, 1.00000] [ True  True]
# Point after epoch 72: [1.00000, 1.00000] [ True  True]
# Point after epoch 73: [1.00000, 1.00000] [ True  True]
# Point after epoch 74: [1.00000, 1.00000] [ True  True]
# Point after epoch 75: [1.00000, 1.00000] [ True  True]
# Point after epoch 76: [1.00000, 1.00000] [ True  True]
# Point after epoch 77: [1.00000, 1.00000] [ True  True]
# Point after epoch 78: [1.00000, 1.00000] [ True  True]
# Point after epoch 79: [1.00000, 1.00000] [ True  True]
# Point after epoch 80: [1.00000, 1.00000] [ True  True]
# Point after epoch 81: [1.00000, 1.00000] [ True  True]
# Point after epoch 82: [1.00000, 1.00000] [ True  True]
# Point after epoch 83: [1.00000, 1.00000] [ True  True]
# Point after epoch 84: [1.00000, 1.00000] [ True  True]
# Point after epoch 85: [1.00000, 1.00000] [ True  True]
# Point after epoch 86: [1.00000, 1.00000] [ True  True]
# Point after epoch 87: [1.00000, 1.00000] [ True  True]
# Point after epoch 88: [1.00000, 1.00000] [ True  True]
# Point after epoch 89: [1.00000, 1.00000] [ True  True]
# Point after epoch 90: [1.00000, 1.00000] [ True  True]
# Point after epoch 91: [1.00000, 1.00000] [ True  True]
# Point after epoch 92: [1.00000, 1.00000] [ True  True]
# Point after epoch 93: [1.00000, 1.00000] [ True  True]
# Point after epoch 94: [1.00000, 1.00000] [ True  True]
# Point after epoch 95: [1.00000, 1.00000] [ True  True]
# Point after epoch 96: [1.00000, 1.00000] [ True  True]
# Point after epoch 97: [1.00000, 1.00000] [ True  True]
# Point after epoch 98: [1.00000, 1.00000] [ True  True]
# Point after epoch 99: [1.00000, 1.00000] [ True  True]
